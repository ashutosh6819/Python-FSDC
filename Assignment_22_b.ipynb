# %% [markdown]
# 1. What is the result of the code, and explain?
#
# X = 'iNeuron'
# def func():
# print(X)
#
# func()
#
#     Answer - 'iNeuron' will be outcome because no value is define for X inside the function so it is taking X value from outside.
#
# 2. What is the result of the code, and explain?
#
# X = 'iNeuron'
# def func():
# X = 'NI!'
#
# func()
# print(X)
#
#     Answer - 'iNeuron' will be outcome of it because it is defined outside of function
#
# 3. What does this code print, and why?
#
# X ='iNeuron'
# def func():
# X = 'NI'
# print(X)
#
# func()
# print(X)
#
#     Answer -
#
#     NI
#
#     'iNeuron'
#
#     because when we pass function it give us the value of X for inside the function (NI) and then when we print(X) it gives us value of X for outside the function ('iNeuron') as it is outside the function
#
# 4. What output does this code produce? Why?
#
# X = 'iNeuron'
# def func():
# global X
# X = 'NI'
#
# func()
# print(X)
#
#     Answer - It will give outcome as - 'NI' n Because global keyword allows you to modify the variable outside of the current scope. It is used to create a global variable and make changes to the variable in a local context.
#
# 5. What about this code—what’s the output, and why?
#
# X = 'iNeuron'
# def func():
# X = 'NI'
# def nested():
# print(X)
# nested()
#
# func()
# print(X)
#
#     Answer -
#     iNeuron
#     iNeuron
#
#     are going to be output as there is no value is define for X inside the nested function so it take it from outside and
#
#     func() will give no output as function dosen't define the output of function
#
#     print(X) is simply giving output as it definr the value
#
# 6. How about this code: what is its output in Python 3, and explain?
#
# def func():
#     X = 'NI'
#     def nested():
#         nonlocal X
#         X = 'Spam'
#     nested()
#     print(X)
#
#
#
# func()
#
#     Answer - spam will be the output because The nonlocal keyword is used to work with variables inside nested functions, where the variable should not belong to the inner function. Use the keyword nonlocal to declare that the variable is not local.
